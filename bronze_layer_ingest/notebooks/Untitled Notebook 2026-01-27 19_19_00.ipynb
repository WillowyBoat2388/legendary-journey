# %%
spark.read.table("outlake.landing.`well-telemetry`").schema
# Out:
# StructType([StructField('client_id', StringType(), True), StructField('well_id', StringType(), True), StructField('sensor_id', StringType(), True), StructField('sensor_type', StringType(), True), StructField('location', StringType(), True), StructField('timestamp', DoubleType(), True), StructField('value', DoubleType(), True), StructField('unit', StringType(), True), StructField('quality', StringType(), True), StructField('status', StringType(), True), StructField('partition_identity', StringType(), True), StructField('_rescued_data', StringType(), True)])
