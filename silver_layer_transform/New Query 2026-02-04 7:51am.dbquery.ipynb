-- %%
-- select * from firm_info;
select client_id from lease
order by client_id, timestamp
limit 100
-- select * from raw.`facility-telemetry` limit 100

-- select * from raw.`well-telemetry` limit 100
